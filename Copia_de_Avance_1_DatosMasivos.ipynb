# %% [markdown]
# <a href="https://colab.research.google.com/github/marcgym2/big-data/blob/main/Copia_de_Avance_1_DatosMasivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import librosa
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt
import tensorflow as tf
from concurrent.futures import ThreadPoolExecutor
import time
import logging
import os
from sklearn.model_selection import train_test_split

# %%
class myCallback(tf.keras.callbacks.Callback):
        # Define the correct function signature for on_epoch_end
        def on_epoch_end(self, epoch, logs={}):
            if logs.get('accuracy') > 0.99:
                print("\nReached 99% accuracy so cancelling training!")

                # Stop training once the above condition is met
                self.model.stop_training = True

# %%
# directorios de las canciones
dir_banda = "/content/Songs"
dir_tumbados = "/content/Songs2"

# listas para almacenar los datos de entrenamiento y las etiquetas
X_train = []
y_train = []
spectrograms = []
num_segments = 20
duration = 5
df = pd.DataFrame(columns=['Archivo', 'Duración', 'Etiqueta'])

# verificar si los directorios existen
print(os.path.exists(dir_banda))
print(os.path.exists(dir_tumbados))
# Out:
# True
# True

# %%
def process_files_and_update_df(dir_path, X_train, y_train, df, duration, label, num_segments):
    df_list = []
    spectrograms = []

    for root, dirs, files in os.walk(dir_path):
        for file in files:
            if file.endswith(".mp3"):
                file_path = os.path.join(root, file)

                for i in range(num_segments):
                    offset_time = i * duration
                    signal, sample_rate = librosa.load(file_path, sr=22050, offset=offset_time, duration=duration, res_type='soxr_lq')

                    if len(signal) < sample_rate * duration:
                        print(f"El segmento de la canción {file} es demasiado corto para {duration} segundos.")
                        continue

                    # Display an ordinary (linear) spectrogram, computing the short-time Fourier transform, and then mapping the magnitudes to a decibel scale.
                    #D = librosa.stft(signal)  # STFT of signal
                    #S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)

                    #mels
                    S_mel = librosa.feature.melspectrogram(y= signal, sr=sample_rate)
                    # Convertimos a log scale (dB). Usaremos el valor de potencia máximo como referencia.
                    S_db = librosa.power_to_db(S_mel, ref=np.max) #Transf. para visualizar



                    X_train.append(S_mel)
                    y_train.append(label)

                    temp_df = pd.DataFrame({
                        'Archivo': [file],
                        'Duración': [duration],
                        'Etiqueta': [label]
                    })
                    df_list.append(temp_df)

                    spectrograms.append(S_db)

    df = pd.concat([df] + df_list, ignore_index=True)

    return X_train, y_train, df, spectrograms


def process_files(dir_path, duration, label):
    X_train = []
    y_train = []
    df = pd.DataFrame()
    spectrograms = []

    X_train, y_train, df, spectrograms = process_files_and_update_df(dir_path, X_train, y_train, df, duration, label, num_segments)
    return X_train, y_train, df, spectrograms

with ThreadPoolExecutor(max_workers=2) as executor:  # Incrementar el número de workers si es necesario
    future_banda = executor.submit(process_files, dir_banda, duration, 0)
    future_tumbados = executor.submit(process_files, dir_tumbados, duration, 1)

# Obtener resultados
X_train_banda, y_train_banda, df_banda, spectrograms_banda = future_banda.result()
X_train_tumbados, y_train_tumbados, df_tumbados, spectrograms_tumbados = future_tumbados.result()

# Combinar los resultados
X_train = X_train_banda + X_train_tumbados
y_train = y_train_banda + y_train_tumbados
df = pd.concat([df_banda, df_tumbados], ignore_index=True)
spectrograms = spectrograms_banda + spectrograms_tumbados

# Visualizar 12 espectrogramas, 6 de cada género
fig, ax = plt.subplots(4, 3, figsize=(15, 10))

fig.suptitle('Espectrogramas de ambos géneros', fontsize=16)

positions = [0, 20, 40, 60, 80, 100]  # Posiciones que quieres graficar

sample_rate = 22050
num_plots = 6
for i, pos in enumerate(positions):
    img = librosa.display.specshow(spectrograms_banda[pos], sr=sample_rate, x_axis='time', y_axis='log', ax=ax[i//3, i%3])
    if i == 0:
        ax[i//3, i%3].set_title("Banda")
    ax[i//3, i%3].set_xlabel(f"Canción: {df_banda['Archivo'][pos]}")
    fig.colorbar(img, ax=ax[i//3, i%3], format="%+2.f dB")

for i, pos in enumerate(positions):
    img = librosa.display.specshow(spectrograms_tumbados[pos], sr=sample_rate, x_axis='time', y_axis='log', ax=ax[(i + num_plots)//3, (i + num_plots)%3])
    if i == 0:
        ax[(i + num_plots)//3, (i + num_plots)%3].set_title("Tumbados")
    ax[(i + num_plots)//3, (i + num_plots)%3].set_xlabel(f"Canción: {df_tumbados['Archivo'][pos]}")
    fig.colorbar(img, ax=ax[(i + num_plots)//3, (i + num_plots)%3], format="%+2.f dB")

plt.tight_layout()
plt.show()

# %% [markdown]
# Ref https://codigofacilito.com/articulos/pool-threads-python

# %%
print(df)
# Out:
#                                Archivo  Duración  Etiqueta
# 0     Todo tuyo CD 1 TRACK 7 (320).mp3         5         0
# 1     Todo tuyo CD 1 TRACK 7 (320).mp3         5         0
# 2     Todo tuyo CD 1 TRACK 7 (320).mp3         5         0
# 3     Todo tuyo CD 1 TRACK 7 (320).mp3         5         0
# 4     Todo tuyo CD 1 TRACK 7 (320).mp3         5         0
# ...                                ...       ...       ...
# 1995          Dan Sanchez - Una 45.mp3         5         1
# 1996          Dan Sanchez - Una 45.mp3         5         1
# 1997          Dan Sanchez - Una 45.mp3         5         1
# 1998          Dan Sanchez - Una 45.mp3         5         1
# 1999          Dan Sanchez - Una 45.mp3         5         1
#
# [2000 rows x 3 columns]

# %%
# Convertir a numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

# Dividir los datos en conjuntos de entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Normalizar los datos de entrenamiento
X_train = np.array([(x - np.min(x)) / (np.max(x) - np.min(x)) for x in X_train])
X_train = np.array([x / np.std(x) for x in X_train])

# Normalizar los datos de validación
X_val = np.array([(x - np.min(X_train)) / (np.max(X_train) - np.min(X_train)) for x in X_val])
X_val = np.array([x / np.std(X_train) for x in X_val])

# Añadir dimensión de canales si es necesario
if len(X_train.shape) == 3:
    X_train = np.expand_dims(X_train, axis=-1)
if len(X_val.shape) == 3:
    X_val = np.expand_dims(X_val, axis=-1)

# Imprimir información detallada sobre los datos de entrenamiento
num_samples, num_frames, num_bins, num_channels = X_train.shape
input_shape = (num_frames, num_bins, num_channels)  # Define input_shape como una tupla de enteros
print(f"Total number of training set: {num_samples}")
print(f"Each sample is a spectrogram of shape {input_shape[0]}x{input_shape[1]}x{input_shape[2]}")
print(f"Therefore, the input shape for the model should be {input_shape}")

# Imprimir información detallada sobre las etiquetas de entrenamiento
num_labels = y_train.shape[0]
unique_labels, counts_labels = np.unique(y_train, return_counts=True)
print(f"Total number of training labels: {num_labels}")
for label, count in zip(unique_labels, counts_labels):
    print(f"Label {label} appears {count} times in the training set")

# Imprimir información detallada sobre los datos de validación
num_samples_val, num_frames_val, num_bins_val, num_channels_val = X_val.shape
print(f"Total number of validation set: {num_samples_val}")

# Imprimir información detallada sobre las etiquetas de validación
num_labels_val = y_val.shape[0]
unique_labels_val, counts_labels_val = np.unique(y_val, return_counts=True)
print(f"Total number of validation labels: {num_labels_val}")
for label, count in zip(unique_labels_val, counts_labels_val):
    print(f"Label {label} appears {count} times in the validation set")
# Out:
# Total number of training set: 1600
# Each sample is a spectrogram of shape 128x216x1
# Therefore, the input shape for the model should be (128, 216, 1)
# Total number of training labels: 1600
# Label 0 appears 801 times in the training set
# Label 1 appears 799 times in the training set
# Total number of validation set: 400
# Total number of validation labels: 400
# Label 0 appears 199 times in the validation set
# Label 1 appears 201 times in the validation set

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(1, activation='sigmoid'))

# Inicializar un planificador de la tasa de aprendizaje que reduzca la tasa después de 10 épocas sin mejora
# lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

# Inicializar Early Stopping para detener el entrenamiento después de 10 épocas sin mejora
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# Compilar el modelo
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Entrenar el modelo
callbacks = myCallback()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32,
                    callbacks=[early_stopping, callbacks])
# Out:
# Epoch 1/50
# 50/50 [==============================] - 4s 56ms/step - loss: 0.6667 - accuracy: 0.5813 - val_loss: 0.6388 - val_accuracy: 0.7075
# Epoch 2/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5986 - accuracy: 0.6687 - val_loss: 0.6267 - val_accuracy: 0.7050
# Epoch 3/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5533 - accuracy: 0.7050 - val_loss: 0.5937 - val_accuracy: 0.7200
# Epoch 4/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4770 - accuracy: 0.7700 - val_loss: 0.5443 - val_accuracy: 0.6900
# Epoch 5/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3833 - accuracy: 0.8263 - val_loss: 0.4750 - val_accuracy: 0.7400
# Epoch 6/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3914 - accuracy: 0.8356 - val_loss: 0.4304 - val_accuracy: 0.7800
# Epoch 7/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3743 - accuracy: 0.8444 - val_loss: 0.3867 - val_accuracy: 0.8175
# Epoch 8/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3361 - accuracy: 0.8494 - val_loss: 0.4055 - val_accuracy: 0.7900
# Epoch 9/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3275 - accuracy: 0.8650 - val_loss: 0.4436 - val_accuracy: 0.7800
# Epoch 10/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2807 - accuracy: 0.8894 - val_loss: 0.3683 - val_accuracy: 0.8400
# Epoch 11/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2619 - accuracy: 0.8869 - val_loss: 0.3711 - val_accuracy: 0.8200
# Epoch 12/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2428 - accuracy: 0.8925 - val_loss: 0.3033 - val_accuracy: 0.8750
# Epoch 13/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2303 - accuracy: 0.9044 - val_loss: 0.2468 - val_accuracy: 0.9150
# Epoch 14/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2432 - accuracy: 0.8994 - val_loss: 0.3806 - val_accuracy: 0.8050
# Epoch 15/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2239 - accuracy: 0.9069 - val_loss: 0.3335 - val_accuracy: 0.8350
# Epoch 16/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2060 - accuracy: 0.9081 - val_loss: 0.2847 - val_accuracy: 0.8675
# Epoch 17/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2129 - accuracy: 0.9106 - val_loss: 0.2866 - val_accuracy: 0.8675
# Epoch 18/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1958 - accuracy: 0.9225 - val_loss: 0.2810 - val_accuracy: 0.8525
# Epoch 19/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1798 - accuracy: 0.9194 - val_loss: 0.2345 - val_accuracy: 0.9150
# Epoch 20/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1783 - accuracy: 0.9244 - val_loss: 0.2501 - val_accuracy: 0.8925
# Epoch 21/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1349 - accuracy: 0.9450 - val_loss: 0.2010 - val_accuracy: 0.9100
# Epoch 22/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1755 - accuracy: 0.9250 - val_loss: 0.3148 - val_accuracy: 0.8500
# Epoch 23/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1607 - accuracy: 0.9381 - val_loss: 0.2492 - val_accuracy: 0.8900
# Epoch 24/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1265 - accuracy: 0.9450 - val_loss: 0.2110 - val_accuracy: 0.9100
# Epoch 25/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1372 - accuracy: 0.9425 - val_loss: 0.2882 - val_accuracy: 0.8500
# Epoch 26/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1229 - accuracy: 0.9525 - val_loss: 0.2764 - val_accuracy: 0.8725
# Epoch 27/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1221 - accuracy: 0.9488 - val_loss: 0.2440 - val_accuracy: 0.8850
# Epoch 28/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1112 - accuracy: 0.9519 - val_loss: 0.2454 - val_accuracy: 0.8925
# Epoch 29/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1367 - accuracy: 0.9481 - val_loss: 0.2414 - val_accuracy: 0.9000
# Epoch 30/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1088 - accuracy: 0.9556 - val_loss: 0.2949 - val_accuracy: 0.8550
# Epoch 31/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1179 - accuracy: 0.9525 - val_loss: 0.1851 - val_accuracy: 0.9325
# Epoch 32/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1154 - accuracy: 0.9594 - val_loss: 0.1893 - val_accuracy: 0.9350
# Epoch 33/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1174 - accuracy: 0.9519 - val_loss: 0.2716 - val_accuracy: 0.8775
# Epoch 34/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1023 - accuracy: 0.9631 - val_loss: 0.2130 - val_accuracy: 0.9150
# Epoch 35/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0858 - accuracy: 0.9650 - val_loss: 0.2326 - val_accuracy: 0.9025
# Epoch 36/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0954 - accuracy: 0.9594 - val_loss: 0.2156 - val_accuracy: 0.9025
# Epoch 37/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0935 - accuracy: 0.9688 - val_loss: 0.2171 - val_accuracy: 0.9025
# Epoch 38/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0696 - accuracy: 0.9762 - val_loss: 0.1712 - val_accuracy: 0.9350
# Epoch 39/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0936 - accuracy: 0.9681 - val_loss: 0.2255 - val_accuracy: 0.9075
# Epoch 40/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0788 - accuracy: 0.9719 - val_loss: 0.1893 - val_accuracy: 0.9300
# Epoch 41/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0890 - accuracy: 0.9619 - val_loss: 0.2069 - val_accuracy: 0.9050
# Epoch 42/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0792 - accuracy: 0.9700 - val_loss: 0.1737 - val_accuracy: 0.9300
# Epoch 43/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0791 - accuracy: 0.9750 - val_loss: 0.1714 - val_accuracy: 0.9275
# Epoch 44/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0638 - accuracy: 0.9737 - val_loss: 0.1980 - val_accuracy: 0.9175
# Epoch 45/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0790 - accuracy: 0.9694 - val_loss: 0.2318 - val_accuracy: 0.9050
# Epoch 46/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0732 - accuracy: 0.9675 - val_loss: 0.1953 - val_accuracy: 0.9175
# Epoch 47/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0808 - accuracy: 0.9638 - val_loss: 0.1644 - val_accuracy: 0.9350
# Epoch 48/50
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0703 - accuracy: 0.9719 - val_loss: 0.2074 - val_accuracy: 0.9100
# Epoch 49/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0665 - accuracy: 0.9775 - val_loss: 0.1631 - val_accuracy: 0.9450
# Epoch 50/50
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0562 - accuracy: 0.9756 - val_loss: 0.2019 - val_accuracy: 0.9275

# %%
# Imprimir un resumen del modelo
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 126, 214, 8)       80
#
#  max_pooling2d_25 (MaxPoolin  (None, 63, 107, 8)       0
#  g2D)
#
#  dropout_30 (Dropout)        (None, 63, 107, 8)        0
#
#  conv2d_26 (Conv2D)          (None, 61, 105, 16)       1168
#
#  max_pooling2d_26 (MaxPoolin  (None, 30, 52, 16)       0
#  g2D)
#
#  dropout_31 (Dropout)        (None, 30, 52, 16)        0
#
#  conv2d_27 (Conv2D)          (None, 28, 50, 32)        4640
#
#  max_pooling2d_27 (MaxPoolin  (None, 14, 25, 32)       0
#  g2D)
#
#  dropout_32 (Dropout)        (None, 14, 25, 32)        0
#
#  conv2d_28 (Conv2D)          (None, 12, 23, 64)        18496
#
#  max_pooling2d_28 (MaxPoolin  (None, 6, 11, 64)        0
#  g2D)
#
#  dropout_33 (Dropout)        (None, 6, 11, 64)         0
#
#  conv2d_29 (Conv2D)          (None, 4, 9, 128)         73856
#
#  max_pooling2d_29 (MaxPoolin  (None, 2, 4, 128)        0
#  g2D)
#
#  dropout_34 (Dropout)        (None, 2, 4, 128)         0
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 256)               262400
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 360,897
# Trainable params: 360,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Obtener los datos del entrenamiento
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# Crear una nueva figura
plt.figure(figsize=(12, 5))

# Subplot para la precisión
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

# Subplot para la pérdida
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Asegurarse de que los subplots no se superponen y mostrar el gráfico
plt.tight_layout()
plt.show()
